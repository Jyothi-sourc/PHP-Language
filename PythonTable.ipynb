# %%
# Christopher Figueroa
# Python table example

# imports pandas for table generation
import pandas as pd

# import for graph generation
#import plotly
#import plotly.graph_objs as go
#import pandas as pd

# %%
# reads the data
cost = pd.read_csv('Cost_of_Living.csv')
cost.head()
# Out:
#               Items  Santa Marta, Colombia  Iloilo, Phillipines  \
# 0           Housing                  300.0                400.0
# 1              Food                   90.0                120.0
# 2         Utilities                   90.0                100.0
# 3          Internet                   30.0                 30.0
# 4  Health Insurance                   80.0                 45.0
#
#    Valencia, Spain  Tokyo, Japan  Amsterdam, The Netherlands  Dubai, UAE  \
# 0            750.0        1200.0                      1500.0      1700.0
# 1            170.0         300.0                       250.0       250.0
# 2            140.0         160.0                       240.0       160.0
# 3             60.0          60.0                        80.0       160.0
# 4             40.0         110.0                       120.0       110.0
#
#    Hong Kong, China  Miami Beach, Florida  San Francisco, California  \
# ...

# %%
# prints out dataframe as html code
html = cost.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Items</th>
#       <th>Santa Marta, Colombia</th>
#       <th>Iloilo, Phillipines</th>
#       <th>Valencia, Spain</th>
#       <th>Tokyo, Japan</th>
#       <th>Amsterdam, The Netherlands</th>
#       <th>Dubai, UAE</th>
#       <th>Hong Kong, China</th>
#       <th>Miami Beach, Florida</th>
#       <th>San Francisco, California</th>
#       <th>Zurich, Switzerland</th>
#       <th>Items.1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Housing</td>
#       <td>300.0</td>
#       <td>400.0</td>
#       <td>750.0</td>
#       <td>1200.0</td>
#       <td>1500.0</td>
#       <td>1700.0</td>
#       <td>2200.0</td>
#       <td>1800.0</td>
#       <td>2500.0</td>
#       <td>2700.0</td>
#       <td>Housing</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Food</td>
#       <td>90.0</td>
#       <td>120.0</td>
# ...
